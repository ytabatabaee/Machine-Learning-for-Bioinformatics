# %%
from sklearn.datasets import load_iris
import numpy as np
from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

import torch

# %% [markdown]
# ## loading Dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
X = torch.tensor(X).float()
y = torch.tensor(np.eye(3)[y]).float()

# %%
X.shape, y.shape
# Out:
# (torch.Size([150, 4]), torch.Size([150, 3]))

# %% [markdown]
# ## MLP
#
# #### Complete the MLP.py, and then import it

# %%
from MLP import *

# %%
mlp = MLP()
mlp.train(X, y, 80)
# Out:
# ...
# 1 loss: 1018.0220947265625 acc: 0.16
# 2 loss: 1017.8822021484375 acc: 0.16
# 3 loss: 1017.7427368164062 acc: 0.16666666666666666
# 4 loss: 1017.6033325195312 acc: 0.17333333333333334
# 5 loss: 1017.4641723632812 acc: 0.17333333333333334
# 6 loss: 1017.3253173828125 acc: 0.17333333333333334
# 7 loss: 1017.1866455078125 acc: 0.17333333333333334
# 8 loss: 1017.0482788085938 acc: 0.17333333333333334
# 9 loss: 1016.91015625 acc: 0.17333333333333334
# 10 loss: 1016.7721557617188 acc: 0.17333333333333334
# 11 loss: 1016.6343994140625 acc: 0.18
# 12 loss: 1016.4969482421875 acc: 0.18
# 13 loss: 1016.3596801757812 acc: 0.18
# 14 loss: 1016.22265625 acc: 0.18
# 15 loss: 1016.0858764648438 acc: 0.18
# 16 loss: 1015.9493408203125 acc: 0.18
# 17 loss: 1015.8130493164062 acc: 0.18
# 18 loss: 1015.6770629882812 acc: 0.19333333333333333
# 19 loss: 1015.5410766601562 acc: 0.19333333333333333
# 20 loss: 1015.4054565429688 acc: 0.19333333333333333
# 21 loss: 1015.27001953125 acc: 0.2
# ...

# %% [markdown]
# ## plotting performance

# %%
plt.figure()
plt.subplot(2,1,1)
plt.title('loss')
plt.plot(mlp.hist['loss'])

plt.subplot(2,1,2)
plt.title('acc')
plt.plot(mlp.hist['acc'])
plt.show()

# %% [markdown]
# We can see that our loss is progressively decreasing and the accuracy is increasing. This shows that the model is learning. If we use higher epochs, we will probably reach higher accuracies.
