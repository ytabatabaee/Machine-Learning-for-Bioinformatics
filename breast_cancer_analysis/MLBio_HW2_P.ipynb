# %% [markdown]
# # Machine Learning in Bioinformatics

# %% [markdown]
# # Homework 2:
#  !!! If you don't fill these fields, your homework does not count !!!<by/>
#  #### first name and last name : Yasamin Tabatabaee
#  #### student number : 95104866

# %% [markdown]
# You can run cells by hitting `Shift` + `Enter` or `ctrl` + `Enter`. <br/>
# We highly recommend you to read each line of code carefully and try to understand what it exactly does. <br/>
# Just alter the parts that is between green comments and specified for you. Please do not change other parts.

# %%
# importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)
from tabulate import tabulate

# %% [markdown]
# # Problem 1. soft margin SVM
# ### about the Data:<br/>
# The purpose of this project is to classify tumors into malignant or benign. The following dataset is constructed based on images of tumors. Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.
# For more details about the features of this dataset you can visit this link:
# https://scikit-learn.org/stable/datasets/index.html#breast-cancer-dataset<br/>
# This dataset contains 30 features and 1 label that is called target. We should find a proper hyperplane that separates malignant and benign samples.
# The original dataset labels is 0 and 1 and in the following code boxes we change it to -1 and 1.

# %%
cancer = load_breast_cancer()
df = pd.DataFrame(np.c_[cancer["data"], cancer["target"]], columns = np.append(cancer["feature_names"],["target"]))
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890     0.0
# 1          0.2750                  0.08902     0.0
# 2          0.3613                  0.08758     0.0
# 3          0.6638                  0.17300     0.0
# 4          0.2364                  0.07678     0.0
#
# [5 rows x 31 columns]

# %%
cancer.target = np.where(cancer.target==0, -1, cancer.target) 
X_train ,X_test ,X_val ,y_train ,y_test ,y_val = None ,None ,None ,None ,None ,None
################################################################################
# TODO: using train_test_split package, split your data into 3 numpy array     #
# called X_train, X_test, and X_val and also split the corresponding labels as #
# y_train, y_test, and y_val. After spliting, the ratio of your data should be # 
# approximately like this:                                                     #
#  Train : 72%     test : 20%       validation : 8%                            #
################################################################################

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size = 0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1)

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
print((X_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_val.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_val.shape[0]/cancer.data.shape[0]) * 100, "%")
# Out:
# 71.8804920913884 %
# 71.8804920913884 %
# 20.035149384885763 %
# 20.035149384885763 %
# 8.084358523725834 %
# 8.084358523725834 %

# %% [markdown]
# ### soft margin SVM optimization:<br/>
# We add 1 at the beginning of each Xs data (X_train, X_val , ...) and then the bias will be calculated implicitly.
# Then you should minimize the following SVM loss function (using gradient descent) with changing parameters of model.<br>
# In this notation:
# \begin{equation}
# x_i , y_i
# \end{equation}
# refers to feature vector of the sample and the label of our training data<br>
# and this is SVM loss function:
#
# \begin{equation}
# \large
# J(W) = \frac{1}{N} \sum_{i=1}^{N}{L^{(i)}} + \frac{\lambda}{2} ||W||^2\\
# \large
# L^{(i)} ={max(0, 1 - y_i(w^{T}x_i)})
# \;\\
# \end{equation}

# %%
# >>>>>WARNING: RUN THIS CELL ONLY ONCE!<<<<<

# adding 1s to the end of feature vectors to be multiplied by bias term of weights
X_val = np.insert(X_val, 0, 1, axis=1)
X_train = np.insert(X_train, 0, 1, axis=1)
X_test = np.insert(X_test, 0, 1, axis=1)
print(X_train.shape)  
print(X_val.shape)  
print(X_test.shape)
# Out:
# (409, 31)
# (46, 31)
# (114, 31)

# %% [markdown]
# Complete the following functions in SVM class. In the part that you should compute loss function of this class, you are not allowed to use "for" loop.

# %%
class SVM:
    def __init__(self, n_features: int, std: float):
        """
        n_features: number of features in (or the dimension of) each instance
        std: standard deviation used in the initialization of the weights of svm
        """
        self.n_features = n_features
        ################################################################################
        # TODO: Initialize the weights of svm using random normal distribution with    #
        # standard deviation equals to std.                                            #
        ################################################################################

        self.w = np.random.normal(scale=std, size=n_features)

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):
        """
        X: training instances as a 2d-array with shape (num_train, n_features)
        y: labels corresponsing to the given training instances as a 1d-array with shape (num_train,)
        reg_coeff: L2-regularization coefficient
        """
        loss = 0.0
        
        #################################################################################
        # TODO: Compute the hinge loss specified in the notebook and save it in the loss#                                                   # loss variable.                                                               #
        # NOTE: YOU ARE NOT ALLOWED TO USE FOR LOOPS!                                   #
        # Don't forget L2-regularization term in your implementation!                   #
        #################################################################################
        
        hinge_loss = np.maximum(0, 1 - y * np.dot(X, self.w))
        loss = np.sum(hinge_loss) / self.n_features + reg_coeff / 2 * np.linalg.norm(self.w) ** 2

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return loss
        
    def update_weights(self,  X: np.ndarray, y: np.ndarray, learning_rate: float , reg_coeff: float):
        """
        Updates the weights of the svm using the gradient of computed loss with respect to the weights. 
        learning_rate: learning rate that will be used in gradient descent to update the weights
        """
        ################################################################################
        # TODO: Compute the gradient of loss computed above w.r.t the svm weights.     #
        # and then update self.w with the computed gradient.                           #
        # (don't forget learning rate and reg_coeff in update rule)                    #
        # Don't forget L2-regularization term in your implementation!                  #
        ################################################################################
        
        loss = np.maximum(0, 1 - y * np.dot(X, self.w))
        loss_indicator = np.zeros(loss.shape)
        loss_indicator[loss > 0] = 1
        gradient = 0.0
        for i in range(self.n_features):
            gradient += reg_coeff * self.w - loss_indicator[i] * X[i] * y[i]    
        self.w = self.w - learning_rate * gradient / self.n_features

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
    def predict(self, X):
        """
        X: Numpy 2d-array of instances
        """
        y_pred = None
        ################################################################################
        # TODO: predict the labels for the instances in X and save them in y_pred.     #                                      #
        ################################################################################

        y_pred = np.sign(np.dot(X, self.w))
        
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return y_pred

# %% [markdown]
# This cell contains your hyper parameters:

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8

# %% [markdown]
# In this cell using your SVM class, we want to train our model for cancer data:<br/>
# In every iteration you should see your training loss decrease.

# %%
from sklearn.metrics import accuracy_score
model = SVM(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 13.673703, val acc 76.09%
# iteration 100, loss 13.220285, val acc 76.09%
# iteration 200, loss 12.766877, val acc 23.91%
# iteration 300, loss 12.326071, val acc 23.91%
# iteration 400, loss 12.093623, val acc 23.91%
# iteration 500, loss 12.015237, val acc 23.91%
# iteration 600, loss 12.001015, val acc 23.91%
# iteration 700, loss 11.991334, val acc 23.91%
# iteration 800, loss 11.971461, val acc 23.91%
# iteration 900, loss 11.953015, val acc 23.91%
# iteration 1000, loss 11.934111, val acc 23.91%
# iteration 1100, loss 11.915789, val acc 23.91%
# iteration 1200, loss 11.898208, val acc 23.91%
# iteration 1300, loss 11.881814, val acc 23.91%
# iteration 1400, loss 11.864266, val acc 23.91%
# iteration 1500, loss 11.846791, val acc 23.91%
# iteration 1600, loss 11.830620, val acc 23.91%
# iteration 1700, loss 11.813395, val acc 23.91%
# iteration 1800, loss 11.796197, val acc 23.91%
# iteration 1900, loss 11.780242, val acc 23.91%
# iteration 2000, loss 11.763044, val acc 23.91%
# iteration 2100, loss 11.745901, val acc 23.91%
# iteration 2200, loss 11.728814, val acc 23.91%
# iteration 2300, loss 11.712994, val acc 23.91%
# iteration 2400, loss 11.695899, val acc 23.91%
# iteration 2500, loss 11.678808, val acc 23.91%
# iteration 2600, loss 11.663307, val acc 23.91%
# iteration 2700, loss 11.646509, val acc 23.91%
# iteration 2800, loss 11.629805, val acc 23.91%
# iteration 2900, loss 11.614612, val acc 23.91%
# iteration 3000, loss 11.598029, val acc 23.91%
# iteration 3100, loss 11.581606, val acc 23.91%
# iteration 3200, loss 11.565193, val acc 23.91%
# iteration 3300, loss 11.550199, val acc 23.91%
# iteration 3400, loss 11.533924, val acc 23.91%
# iteration 3500, loss 11.517689, val acc 23.91%
# iteration 3600, loss 11.501680, val acc 23.91%
# iteration 3700, loss 11.480623, val acc 23.91%
# iteration 3800, loss 11.460811, val acc 23.91%
# iteration 3900, loss 11.441000, val acc 23.91%
# iteration 4000, loss 11.420047, val acc 23.91%
# iteration 4100, loss 11.401159, val acc 23.91%
# iteration 4200, loss 11.382593, val acc 23.91%
# iteration 4300, loss 11.364027, val acc 23.91%
# iteration 4400, loss 11.345464, val acc 23.91%
# iteration 4500, loss 11.325656, val acc 23.91%
# iteration 4600, loss 11.307091, val acc 23.91%
# iteration 4700, loss 11.288527, val acc 23.91%
# iteration 4800, loss 11.269963, val acc 23.91%
# iteration 4900, loss 11.250197, val acc 23.91%
# iteration 5000, loss 11.231736, val acc 23.91%
# iteration 5100, loss 11.213276, val acc 23.91%
# iteration 5200, loss 11.194816, val acc 23.91%
# iteration 5300, loss 11.176438, val acc 23.91%
# iteration 5400, loss 11.156871, val acc 23.91%
# iteration 5500, loss 11.138651, val acc 23.91%
# iteration 5600, loss 11.120432, val acc 23.91%
# iteration 5700, loss 11.102282, val acc 23.91%
# iteration 5800, loss 11.084145, val acc 23.91%
# iteration 5900, loss 11.064662, val acc 23.91%
# iteration 6000, loss 11.046526, val acc 23.91%
# iteration 6100, loss 11.028390, val acc 23.91%
# iteration 6200, loss 11.010255, val acc 23.91%
# iteration 6300, loss 10.992121, val acc 23.91%
# iteration 6400, loss 10.972652, val acc 23.91%
# iteration 6500, loss 10.953839, val acc 23.91%
# iteration 6600, loss 10.933957, val acc 23.91%
# iteration 6700, loss 10.915304, val acc 23.91%
# iteration 6800, loss 10.895423, val acc 23.91%
# iteration 6900, loss 10.875542, val acc 23.91%
# iteration 7000, loss 10.856891, val acc 23.91%
# iteration 7100, loss 10.837048, val acc 23.91%
# iteration 7200, loss 10.817458, val acc 23.91%
# iteration 7300, loss 10.799115, val acc 23.91%
# iteration 7400, loss 10.779922, val acc 23.91%
# iteration 7500, loss 10.760970, val acc 23.91%
# iteration 7600, loss 10.743074, val acc 23.91%
# iteration 7700, loss 10.724122, val acc 23.91%
# iteration 7800, loss 10.705172, val acc 23.91%
# iteration 7900, loss 10.687277, val acc 23.91%
# iteration 8000, loss 10.668414, val acc 23.91%
# iteration 8100, loss 10.649581, val acc 23.91%
# iteration 8200, loss 10.631769, val acc 23.91%
# iteration 8300, loss 10.612934, val acc 23.91%
# iteration 8400, loss 10.594102, val acc 23.91%
# iteration 8500, loss 10.575270, val acc 23.91%
# iteration 8600, loss 10.557457, val acc 23.91%
# iteration 8700, loss 10.538626, val acc 26.09%
# iteration 8800, loss 10.519796, val acc 28.26%
# iteration 8900, loss 10.501984, val acc 28.26%
# iteration 9000, loss 10.483154, val acc 28.26%
# iteration 9100, loss 10.462849, val acc 28.26%
# iteration 9200, loss 10.443443, val acc 28.26%
# iteration 9300, loss 10.423137, val acc 28.26%
# iteration 9400, loss 10.402833, val acc 30.43%
# iteration 9500, loss 10.382529, val acc 30.43%
# iteration 9600, loss 10.362293, val acc 30.43%
# iteration 9700, loss 10.342997, val acc 32.61%
# iteration 9800, loss 10.322835, val acc 32.61%
# iteration 9900, loss 10.302673, val acc 32.61%
# iteration 10000, loss 10.282512, val acc 34.78%
# iteration 10100, loss 10.262387, val acc 41.30%
# iteration 10200, loss 10.243151, val acc 41.30%
# iteration 10300, loss 10.223078, val acc 43.48%
# iteration 10400, loss 10.203006, val acc 45.65%
# iteration 10500, loss 10.182934, val acc 45.65%
# iteration 10600, loss 10.163785, val acc 52.17%
# iteration 10700, loss 10.143974, val acc 56.52%
# iteration 10800, loss 10.124196, val acc 56.52%
# iteration 10900, loss 10.104418, val acc 58.70%
# iteration 11000, loss 10.084641, val acc 60.87%
# iteration 11100, loss 10.065638, val acc 63.04%
# iteration 11200, loss 10.045861, val acc 63.04%
# iteration 11300, loss 10.026085, val acc 63.04%
# iteration 11400, loss 10.006519, val acc 63.04%
# iteration 11500, loss 9.986966, val acc 63.04%
# iteration 11600, loss 9.968124, val acc 63.04%
# iteration 11700, loss 9.948571, val acc 63.04%
# iteration 11800, loss 9.929019, val acc 63.04%
# iteration 11900, loss 9.909467, val acc 63.04%
# iteration 12000, loss 9.889915, val acc 63.04%
# iteration 12100, loss 9.871075, val acc 65.22%
# iteration 12200, loss 9.851525, val acc 65.22%
# iteration 12300, loss 9.831974, val acc 65.22%
# iteration 12400, loss 9.812487, val acc 69.57%
# iteration 12500, loss 9.793739, val acc 69.57%
# iteration 12600, loss 9.774308, val acc 69.57%
# iteration 12700, loss 9.754880, val acc 69.57%
# iteration 12800, loss 9.735491, val acc 69.57%
# iteration 12900, loss 9.716118, val acc 69.57%
# iteration 13000, loss 9.697400, val acc 69.57%
# iteration 13100, loss 9.678028, val acc 69.57%
# iteration 13200, loss 9.658657, val acc 69.57%
# iteration 13300, loss 9.639286, val acc 69.57%
# iteration 13400, loss 9.619916, val acc 71.74%
# iteration 13500, loss 9.601199, val acc 71.74%
# iteration 13600, loss 9.581897, val acc 71.74%
# iteration 13700, loss 9.562666, val acc 76.09%
# iteration 13800, loss 9.543436, val acc 76.09%
# iteration 13900, loss 9.524805, val acc 76.09%
# iteration 14000, loss 9.505573, val acc 78.26%
# iteration 14100, loss 9.486354, val acc 80.43%
# iteration 14200, loss 9.467248, val acc 80.43%
# iteration 14300, loss 9.448142, val acc 82.61%
# iteration 14400, loss 9.429601, val acc 82.61%
# iteration 14500, loss 9.410495, val acc 82.61%
# iteration 14600, loss 9.391391, val acc 82.61%
# iteration 14700, loss 9.372290, val acc 82.61%
# iteration 14800, loss 9.353299, val acc 84.78%
# iteration 14900, loss 9.334837, val acc 84.78%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #
# using loss_loss_history and loss_val_history                                     #
####################################################################################

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Loss Changes')
ax1.set(xlabel='Iteration', ylabel='Loss', xticks = np.arange(0, num_iters + 1, 1000))
ax2.set(xlabel='Iteration', ylabel='Loss', xticks = np.arange(0, num_iters + 1, 1000))
ax1.plot(range(0, num_iters), loss_history, label='Training')
ax2.plot(range(0, num_iters), loss_val_history, label='Validation')
ax1.legend(loc='upper right')
ax2.legend(loc='upper right')
plt.show()    

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 1:
# With changing your hyper parameters, find a configuration of hyper parameters that cause your loss to increase after each iteration and then report that configuration in the next cell. Explain why our loss increases?
# Write your answer in ""

# %% [markdown]
# std = "" <br>
# num_iters = ""<br>
# reg_coeff = ""<br>
# learning_rate = ""<br>

# %% [markdown]
# ### Question 2:
# In this cell please explain the reason of this event<br>
# Answer:

# %%
val_preds =  model.predict(X_test)
###########################################################################################
# TODO: find the Confusion Matrix between val_preds and real labels (y_test) for test data#
# then report the accuracy of the model.                                                  #
# you are not allowed to use any premade function for accuracy and confusion matrix       #
###########################################################################################

def confusion_matrix(y, y_pred):
    tp = np.count_nonzero((y_pred == 1) & (y == 1))
    fp = np.count_nonzero((y_pred == 1) & (y == -1))
    tn = np.count_nonzero((y_pred == -1) & (y == -1))
    fn = np.count_nonzero((y_pred == -1) & (y == 1)) 
    return tp, fp, tn, fn

tp, fp, tn, fn = confusion_matrix(y_test, val_preds)
print(tabulate([['Predicted Positive', tp, fp], ['Predicted Negative', fn, tn]], headers=['', 'Actually Positive', 'Actually Negative']))
accuracy = (tp + tn) / (tp + tn + fp + fn)
print("Accuracy = ", accuracy)

###########################################################################################
#                                END OF YOUR EXPLANATION                                  #
###########################################################################################
# Out:
#                       Actually Positive    Actually Negative
# ------------------  -------------------  -------------------
# Predicted Positive                   63                    2
# Predicted Negative                    7                   42
# Accuracy =  0.9210526315789473

# %% [markdown]
# In the next part, we sample from training data with certain size (batch size) instead of using all the training data in each iteration, and train our model on batch data:

# %%
std = 0.0001
batch_size = 200
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8
model = SVM(n_features=X_train.shape[1], std= std )

# %%
loss_history = []
loss_val_history = []
for it in range(num_iters):
    X_batch = None
    y_batch = None
    ################################################################################
    # TODO: Sample batch_size elements from the training data and their            #
    # corresponding labels to use in this round of gradient descent.               #
    # Store the data in X_batch and their corresponding labels in                  #
    # y_batch; after sampling X_batch should have shape (batch_size, n_features)   #
    # and y_batch should have shape (batch_size,)                                  #
    #                                                                              #
    # Hint: Use np.random.choice to generate indices. Sampling with                #
    # replacement is faster than sampling without replacement.                     #
    ################################################################################

    indices = np.random.choice(X_train.shape[0], batch_size, replace=True)
    X_batch = X_train[indices]
    y_batch = y_train[indices]
    
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################
    loss = model.loss(X_batch, y_batch, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_batch, y_batch, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 6.399298, val acc 23.91%
# iteration 100, loss 6.187880, val acc 23.91%
# iteration 200, loss 5.688584, val acc 23.91%
# iteration 300, loss 5.944802, val acc 23.91%
# iteration 400, loss 6.049134, val acc 23.91%
# iteration 500, loss 5.691396, val acc 23.91%
# iteration 600, loss 5.956324, val acc 23.91%
# iteration 700, loss 5.383063, val acc 23.91%
# iteration 800, loss 5.665232, val acc 23.91%
# iteration 900, loss 5.775318, val acc 23.91%
# iteration 1000, loss 5.862754, val acc 23.91%
# iteration 1100, loss 5.920478, val acc 23.91%
# iteration 1200, loss 6.086372, val acc 23.91%
# iteration 1300, loss 5.701470, val acc 23.91%
# iteration 1400, loss 5.700512, val acc 23.91%
# iteration 1500, loss 5.716749, val acc 23.91%
# iteration 1600, loss 6.070379, val acc 23.91%
# iteration 1700, loss 5.811972, val acc 23.91%
# iteration 1800, loss 6.125349, val acc 23.91%
# iteration 1900, loss 5.772376, val acc 23.91%
# iteration 2000, loss 5.887160, val acc 23.91%
# iteration 2100, loss 5.522721, val acc 23.91%
# iteration 2200, loss 5.609181, val acc 23.91%
# iteration 2300, loss 5.804326, val acc 23.91%
# iteration 2400, loss 5.307536, val acc 23.91%
# iteration 2500, loss 5.658953, val acc 23.91%
# iteration 2600, loss 6.048701, val acc 23.91%
# iteration 2700, loss 5.793526, val acc 23.91%
# iteration 2800, loss 5.093918, val acc 23.91%
# iteration 2900, loss 5.848729, val acc 23.91%
# iteration 3000, loss 6.006512, val acc 23.91%
# iteration 3100, loss 5.849713, val acc 23.91%
# iteration 3200, loss 5.413843, val acc 23.91%
# iteration 3300, loss 6.081897, val acc 23.91%
# iteration 3400, loss 5.975848, val acc 23.91%
# iteration 3500, loss 6.057934, val acc 23.91%
# iteration 3600, loss 5.882185, val acc 23.91%
# iteration 3700, loss 5.970537, val acc 23.91%
# iteration 3800, loss 4.918495, val acc 23.91%
# iteration 3900, loss 6.093186, val acc 23.91%
# iteration 4000, loss 5.295503, val acc 23.91%
# iteration 4100, loss 5.400360, val acc 23.91%
# iteration 4200, loss 5.117134, val acc 23.91%
# iteration 4300, loss 5.491185, val acc 23.91%
# iteration 4400, loss 5.480336, val acc 23.91%
# iteration 4500, loss 5.385989, val acc 23.91%
# iteration 4600, loss 5.571880, val acc 23.91%
# iteration 4700, loss 5.787274, val acc 23.91%
# iteration 4800, loss 5.419434, val acc 23.91%
# iteration 4900, loss 5.345546, val acc 23.91%
# iteration 5000, loss 5.670688, val acc 23.91%
# iteration 5100, loss 5.434936, val acc 23.91%
# iteration 5200, loss 5.491466, val acc 23.91%
# iteration 5300, loss 5.283628, val acc 23.91%
# iteration 5400, loss 5.479815, val acc 23.91%
# iteration 5500, loss 5.521789, val acc 23.91%
# iteration 5600, loss 5.209995, val acc 23.91%
# iteration 5700, loss 5.746700, val acc 23.91%
# iteration 5800, loss 5.509314, val acc 23.91%
# iteration 5900, loss 5.410371, val acc 23.91%
# iteration 6000, loss 5.371576, val acc 23.91%
# iteration 6100, loss 5.491573, val acc 23.91%
# iteration 6200, loss 5.232220, val acc 23.91%
# iteration 6300, loss 5.884002, val acc 23.91%
# iteration 6400, loss 5.499393, val acc 23.91%
# iteration 6500, loss 5.789773, val acc 23.91%
# iteration 6600, loss 4.997827, val acc 23.91%
# iteration 6700, loss 5.666552, val acc 23.91%
# iteration 6800, loss 5.570676, val acc 23.91%
# iteration 6900, loss 4.916222, val acc 23.91%
# iteration 7000, loss 5.339928, val acc 23.91%
# iteration 7100, loss 5.751370, val acc 23.91%
# iteration 7200, loss 5.287842, val acc 23.91%
# iteration 7300, loss 5.287665, val acc 23.91%
# iteration 7400, loss 4.935986, val acc 23.91%
# iteration 7500, loss 4.843039, val acc 23.91%
# iteration 7600, loss 5.412016, val acc 23.91%
# iteration 7700, loss 5.387323, val acc 23.91%
# iteration 7800, loss 4.918502, val acc 23.91%
# iteration 7900, loss 5.638209, val acc 23.91%
# iteration 8000, loss 4.989473, val acc 23.91%
# iteration 8100, loss 5.319063, val acc 23.91%
# iteration 8200, loss 5.235105, val acc 23.91%
# iteration 8300, loss 5.330380, val acc 23.91%
# iteration 8400, loss 5.467215, val acc 23.91%
# iteration 8500, loss 4.921607, val acc 23.91%
# iteration 8600, loss 5.278239, val acc 28.26%
# iteration 8700, loss 5.174367, val acc 28.26%
# iteration 8800, loss 5.210681, val acc 30.43%
# iteration 8900, loss 5.244327, val acc 30.43%
# iteration 9000, loss 5.337010, val acc 30.43%
# iteration 9100, loss 5.286072, val acc 28.26%
# iteration 9200, loss 5.247944, val acc 30.43%
# iteration 9300, loss 5.245912, val acc 30.43%
# iteration 9400, loss 5.012443, val acc 30.43%
# iteration 9500, loss 5.330822, val acc 45.65%
# iteration 9600, loss 5.212550, val acc 45.65%
# iteration 9700, loss 5.334957, val acc 50.00%
# iteration 9800, loss 5.035496, val acc 41.30%
# iteration 9900, loss 5.208656, val acc 43.48%
# iteration 10000, loss 5.287837, val acc 56.52%
# iteration 10100, loss 5.136952, val acc 47.83%
# iteration 10200, loss 5.049800, val acc 43.48%
# iteration 10300, loss 4.899340, val acc 56.52%
# iteration 10400, loss 5.199521, val acc 56.52%
# iteration 10500, loss 5.355233, val acc 60.87%
# iteration 10600, loss 5.324828, val acc 63.04%
# iteration 10700, loss 5.203544, val acc 56.52%
# iteration 10800, loss 4.894183, val acc 56.52%
# iteration 10900, loss 5.240561, val acc 56.52%
# iteration 11000, loss 5.047903, val acc 60.87%
# iteration 11100, loss 5.162808, val acc 63.04%
# iteration 11200, loss 5.006960, val acc 63.04%
# iteration 11300, loss 4.894929, val acc 63.04%
# iteration 11400, loss 5.206615, val acc 69.57%
# iteration 11500, loss 5.069398, val acc 65.22%
# iteration 11600, loss 5.131200, val acc 69.57%
# iteration 11700, loss 4.896285, val acc 69.57%
# iteration 11800, loss 4.931759, val acc 69.57%
# iteration 11900, loss 5.279416, val acc 65.22%
# iteration 12000, loss 4.938361, val acc 63.04%
# iteration 12100, loss 5.118991, val acc 63.04%
# iteration 12200, loss 4.864934, val acc 63.04%
# iteration 12300, loss 4.882168, val acc 63.04%
# iteration 12400, loss 4.803653, val acc 65.22%
# iteration 12500, loss 4.898712, val acc 65.22%
# iteration 12600, loss 4.835166, val acc 69.57%
# iteration 12700, loss 5.087155, val acc 69.57%
# iteration 12800, loss 4.634784, val acc 78.26%
# iteration 12900, loss 5.371945, val acc 69.57%
# iteration 13000, loss 5.060022, val acc 69.57%
# iteration 13100, loss 4.876349, val acc 71.74%
# iteration 13200, loss 4.863377, val acc 69.57%
# iteration 13300, loss 4.959225, val acc 69.57%
# iteration 13400, loss 4.661115, val acc 73.91%
# iteration 13500, loss 4.765918, val acc 76.09%
# iteration 13600, loss 4.906592, val acc 76.09%
# iteration 13700, loss 4.659702, val acc 76.09%
# iteration 13800, loss 4.776799, val acc 76.09%
# iteration 13900, loss 4.858338, val acc 76.09%
# iteration 14000, loss 4.959953, val acc 80.43%
# iteration 14100, loss 4.873558, val acc 82.61%
# iteration 14200, loss 4.987462, val acc 80.43%
# iteration 14300, loss 5.088779, val acc 82.61%
# iteration 14400, loss 4.757727, val acc 84.78%
# iteration 14500, loss 4.973426, val acc 86.96%
# iteration 14600, loss 4.838453, val acc 91.30%
# iteration 14700, loss 4.668557, val acc 89.13%
# iteration 14800, loss 4.932135, val acc 84.78%
# iteration 14900, loss 4.765171, val acc 86.96%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #

####################################################################################

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Loss Changes')
ax1.set(xlabel='Iteration', ylabel='Loss', xticks = np.arange(0, num_iters + 1, 1000))
ax2.set(xlabel='Iteration', ylabel='Loss', xticks = np.arange(0, num_iters + 1, 1000))
ax1.plot(range(0, num_iters), loss_history, label='Training')
ax2.plot(range(0, num_iters), loss_val_history, label='Validation')
ax1.legend(loc='upper right')
ax2.legend(loc='upper right')
plt.show()

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 3:
# Explain why we see fluctuation in this plot?<br>
# Answer:

# %% [markdown]
# # Problem 2. Perceptron

# %% [markdown]
# By now, you should know how to use and how to implement SVM from scratch.
# In fact, for perceptron we can use premade functions as below:

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
val_preds = clf.predict(X_test)
print(confusion_matrix(y_test,val_preds,[1,-1]))
print('test acc %.2f%%' % (accuracy_score(y_test,val_preds) * 100))
# Out:
# [[70  0]
#  [14 30]]
# test acc 87.72%

# %% [markdown]
# ### Question 4:
# It is time for you to write your own code instead of completing some parts of a premade code.<br>
# So you can not use any premade functions like the previous cell.
# Write your code in the end of this .ipynb file <br>
# You should make your model and use that to build these outputs:<br>
# 1- Report loss of training and accuracy of validation data on each epoch of training process.<br>
# 2- You are allowed to use any normalization approach if need be.<br>
# 3- Plot your training and validation loss vs number of iterations in one plot.<br>
# 4- Finally print your confusion matrix and accuracy for your testing set.<br>
# With changing your hyperparameters try to get a good and reasonable accuracy and confusion matrix on testing set (similar to the accuracy when we used the package).

# %%
class Perceptron:
    def __init__(self, n_features: int):
        self.n_features = n_features
        self.w = np.zeros(n_features)
        

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):
        hinge_loss = np.maximum(0, 1 - y * np.dot(X, self.w)) 
        return np.sum(hinge_loss) / self.n_features

    
    def update_weights(self,  X: np.ndarray, y: np.ndarray, learning_rate: float , reg_coeff: float):
        loss = np.maximum(0, 1 - y * np.dot(X, self.w))
        loss_indicator = np.zeros(loss.shape)
        loss_indicator[loss > 0] = 1
        gradient = 0.0
        for i in range(self.n_features):
            gradient += loss_indicator[i] * X[i] * y[i]    
        self.w = self.w + learning_rate * gradient / self.n_features

        
    def predict(self, X):
        y_pred = np.sign(np.dot(X, self.w))
        return y_pred

# %%
# Hyper parameters

num_iters = 15000
learning_rate=1e-8

# %%
# Training

from sklearn.metrics import accuracy_score
model = Perceptron(n_features=X_train.shape[1])
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-0fdba0289e27> in <module>
#       2
#       3 from sklearn.metrics import accuracy_score
# ----> 4 model = Perceptron(n_features=X_train.shape[1])
#       5 loss_history = []
#       6 loss_val_history = []
#
# TypeError: __init__() missing 1 required positional argument: 'std'

# %%
# Training/Validation loss plots

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Loss Changes')
ax1.set(xlabel='Iteration', ylabel='Loss', xticks = np.arange(0, num_iters + 1, 1000))
ax2.set(xlabel='Iteration', ylabel='Loss', xticks = np.arange(0, num_iters + 1, 1000))
ax1.plot(range(0, num_iters), loss_history, label='Training')
ax2.plot(range(0, num_iters), loss_val_history, label='Validation')
ax1.legend(loc='upper right')
ax2.legend(loc='upper right')
plt.show()

# %%
# Confusion Matrix & Accuracy

val_preds =  model.predict(X_test)
def confusion_matrix(y, y_pred):
    tp = np.count_nonzero((y_pred == 1) & (y == 1))
    fp = np.count_nonzero((y_pred == 1) & (y == -1))
    tn = np.count_nonzero((y_pred == -1) & (y == -1))
    fn = np.count_nonzero((y_pred == -1) & (y == 1)) 
    return tp, fp, tn, fn

tp, fp, tn, fn = confusion_matrix(y_test, val_preds)
print(tabulate([['Predicted Positive', tp, fp], ['Predicted Negative', fn, tn]], headers=['', 'Actually Positive', 'Actually Negative']))
accuracy = (tp + tn) / (tp + tn + fp + fn)
print("Accuracy = ", accuracy)
# Out:
#                       Actually Positive    Actually Negative
# ------------------  -------------------  -------------------
# Predicted Positive                   63                    2
# Predicted Negative                    7                   42
# Accuracy =  0.9210526315789473
